# %%
set = {"fast", "i", "have"}
print(type(set))
print(set)
# Out:
# <class 'set'>
# {'have', 'i', 'fast'}

# %%
# adding element to the set
myset = {1,2,3,4,5}
myset.add("d")
print(myset)
# Out:
# {1, 2, 3, 4, 5, 'd'}
