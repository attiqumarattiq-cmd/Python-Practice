# %%
str1 = "YES, "
str2 = "PAK ARMY ZINDABAD"
str3 = str1 + str2
print(str3)
# Out:
# YES, PAK ARMY ZINDABAD

# %%
str3 = '12'
x = int(str3) * 2
print(x)
# Out:
# 24

# %%
#############################
# LOOKING INSIDE STRING
fruit = 'banana'
letter = fruit[1]
print(letter)

x = 3
w = fruit[x-1]
print(w)
# Out:
# a
# n
